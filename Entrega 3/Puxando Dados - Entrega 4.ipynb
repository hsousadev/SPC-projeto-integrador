# %% [markdown]
# # Importando Bibliotecas

# %%
import pandas as pd

# %% [markdown]
# # Puxando os Dados Principais

# %%
modalidade = pd.read_excel('dados/STG_MDL.xlsx')
pagamento = pd.read_excel('dados/STG_PGT.xlsx')
movimento = pd.read_excel('dados/STG_MVT_CRD.xlsx')
operacao = pd.read_excel('dados/STG_OPR_ITT.xlsx')
fonte = pd.read_excel('dados/STG_FNT_ITT.xlsx')

# %% [markdown]
# # Puxando os Dados Complementares

# %%
pessoa_fisica = pd.read_csv("dados/fatec_pessoa_fisica.csv", sep = '|', encoding='UTF-8', header = 1)
endereco_pessoa_fisica = pd.read_csv("dados/fatec_endereco_pessoa_fisica.csv", sep = '|', encoding='UTF-8', header = 1)
fatec_operacao = pd.read_csv("dados/fatec_opr.csv", sep = '|', encoding='UTF-8', header = 1)
fatec_movimento = pd.read_csv("dados/fatec_mvt.csv", sep = '|', encoding='UTF-8', header = 1)
fatec_pagamento = pd.read_csv("dados/fatec_pgt.csv", sep = '|', encoding='UTF-8', header = 1)

# %%
pessoa_fisica.head()
# Out:
#                                           Unnamed: 0   id          \
# 0  +-----------+--------------+----------+-------...          NaN
# 1                                                NaN   804129883
# 2                                                NaN   246036379
# 3                                                NaN   218979283
# 4                                                NaN   717277229
#
#     cpf             idc_sexo    ano_dat_nascimento   Unnamed: 5
# 0             NaN         NaN                   NaN         NaN
# 1   37311167211     M           2000                        NaN
# 2   34115266395     M           1969                        NaN
# 3   35622655491     M           1970                        NaN
# 4   33222324480     F           1994                        NaN

# %%
endereco_pessoa_fisica.head()
# Out:
#                                           Unnamed: 0   id_pessoa_fisica   \
# 0  +------------------+--------------------------...                 NaN
# 1                                                NaN   41173256
# 2                                                NaN   212014803
# 3                                                NaN   252868763
# 4                                                NaN   351777344
#
#     nom_cidade                     des_estado              Unnamed: 4
# 0                            NaN                      NaN         NaN
# 1   TREMEMBE                       SAO PAULO                      NaN
# 2   SALVADOR                       BAHIA                          NaN
# 3   PORTO ALEGRE                   RIO GRANDE DO SUL              NaN
# 4   CORURIPE                       ALAGOAS                        NaN

# %%
fatec_operacao.head()
# Out:
#                                           Unnamed: 0   id_opr_cad_pos   \
# 0  +----------------+--------------+---------+---...               NaN
# 1                                                NaN   0f503289-dfb
# 2                                                NaN   683ea107-f2e
# 3                                                NaN   d8e48899-58d
# 4                                                NaN   5909262c-526
#
#     doc_cli         tip_cli    qtd_pcl    dat_vct_ult_pcl   \
# 0             NaN        NaN        NaN                NaN
# 1   87308050371     F          52         20112023
# 2   54355614187     F          36         06112022
# 3   92265948819     F          NULL       NULL
# 4   104455393515    F          82         20112019
#
#     vlr_ctrd_fta_tfm    sdo_ddr_tfm    vlr_ctrd      \
# 0                 NaN            NaN            NaN
# 1   NULL                259741.1685    28511582.7
# 2   140141.5236         NULL           NULL
# 3   NULL                0.0000         NULL
# 4   NULL                1520.5905      27626512.71
#
#     id_ult_rss_opr                          id_mdl    cod_mdl    id_fnt   \
# 0                                     NaN       NaN        NaN       NaN
# 1   25e351cc-ec4e-4a47-861e-834f2aa1dc13    14        C01        99
# 2   a1f18524-8a4f-40a5-ba31-6fbff83bfd58    10        B05        99
# 3   63149b03-b3bd-41e3-9b33-86661155bbaf    15        D01        179
# 4   40367466-b381-4452-add6-641eafb6b1be    14        C01        99
#
#    Unnamed: 13
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
fatec_movimento.head()
# Out:
#                                           Unnamed: 0   id_opr_cad_pos   \
# 0  +----------------+----------------+----------+...               NaN
# 1                                                NaN   ed78c2f2-fd2
# 2                                                NaN   84706050-586
# 3                                                NaN   7b3bc686-d7f
# 4                                                NaN   57a7735b-83e
#
#     id_mvt_cad_pos    dat_vct     qtd_pcl_vnc    qtd_pcl_pgr   \
# 0               NaN         NaN            NaN            NaN
# 1   64d85edf-8b3      15062019    NULL           NULL
# 2   3e537b64-340      10042019    NULL           NULL
# 3   930e64c5-777      17022019    NULL           NULL
# 4   79bac911-7a0      10022019    NULL           NULL
#
#     vlr_tot_fat_tfm    vlr_min_fat_tfm    vlr_pcl_tfm    tip_mvt    prd    \
# 0                NaN                NaN            NaN        NaN     NaN
# 1   NULL               NULL               2728.3476      ANT        M
# 2   2195.7135          329.3049           NULL           ANT        NULL
# 3   3791.8644          56870.4600         NULL           ANT        NULL
# 4   NULL               NULL               1284.6519      ANT        M
#
#    Unnamed: 11
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
fatec_pagamento.head()
# Out:
#                                           Unnamed: 0   id_opr_cad_pos   \
# 0  +----------------+----------------+-----------...               NaN
# 1                                                NaN   c8176e21-845
# 2                                                NaN   a3fad4d7-ad7
# 3                                                NaN   7fd6249b-4cf
# 4                                                NaN   90fb53f6-225
#
#     id_mvt_cad_pos    id_pgt_cad_pos    dat_pgt     dat_vct_tfm           \
# 0               NaN               NaN         NaN                    NaN
# 1   cd596c84-3fe      f4ef9e73-e02      13102019    2019-10-13 03:00:00
# 2   3736da82-cd3      cffcab96-2b4      01032020    2020-03-01 03:00:00
# 3   f66a2496-e0a      b021cf9e-409      07122018    2019-12-12 03:00:00
# 4   0e3217ed-88e      72854add-8b9      07082019    2019-08-05 03:00:00
#
#     vlr_pgt_tfm    cod_mdl    cmd   Unnamed: 9
# 0            NaN        NaN    NaN         NaN
# 1   591.3060       D01        E            NaN
# 2   6880.2081      D01        E            NaN
# 3   6553.5303      B05        I            NaN
# 4   5980.6140      C01        I            NaN

# %% [markdown]
# ## Limpando o DataFrame
#
# Abaixo estamos definindo o nome da coluna bugada para ser usada na função a seguinte:

# %%
# Exemplo de como é a nomeclatura das colunas antes da alteração:

pessoa_fisica.columns[1:5]
# Out:
# Index([' id        ', ' cpf          ', ' idc_sexo ', ' ano_dat_nascimento '], dtype='object')

# %%
# Definindo as colunas que serão usadas:

pessoa_fisica_colunas = pessoa_fisica.columns[1:len(pessoa_fisica.columns) - 1]
endereco_pessoa_fisica_colunas = endereco_pessoa_fisica.columns[1:len(endereco_pessoa_fisica.columns) - 1]
fatec_operacao_colunas = fatec_operacao.columns[1:len(fatec_operacao.columns) - 1]
fatec_movimento_colunas = fatec_movimento.columns[1:len(fatec_movimento.columns) - 1]
fatec_pagamento_colunas = fatec_pagamento.columns[1:len(fatec_pagamento.columns) - 1]

# %%
# Estamos armazenando um exemplo do nome da coluna, para no código a seguir retirarmos a quebra de página:

coluna_pessoa_fisica = pessoa_fisica.columns[1]
coluna_endereco_pessoa_fisica = endereco_pessoa_fisica.columns[1]
coluna_fatec_operacao = fatec_operacao.columns[1]
coluna_fatec_movimento = fatec_movimento.columns[1]
coluna_fatec_pagamento = fatec_pagamento.columns[1]

# %%
# Demonstração da váriavel: 

coluna_pessoa_fisica
# Out:
# ' id        '

# %% [markdown]
# ## Redefinindo as colunas das tabelas

# %%
pessoa_fisica = pd.DataFrame(pessoa_fisica, columns = pessoa_fisica_colunas)
endereco_pessoa_fisica = pd.DataFrame(endereco_pessoa_fisica, columns = endereco_pessoa_fisica_colunas)
fatec_operacao = pd.DataFrame(fatec_operacao, columns = fatec_operacao_colunas)
fatec_movimento = pd.DataFrame(fatec_movimento, columns = fatec_movimento_colunas)
fatec_pagamento = pd.DataFrame(fatec_pagamento, columns = fatec_pagamento_colunas)

# %%
pessoa_fisica.head()
# Out:
#     id           cpf             idc_sexo    ano_dat_nascimento
# 0          NaN             NaN         NaN                   NaN
# 1   804129883    37311167211     M           2000
# 2   246036379    34115266395     M           1969
# 3   218979283    35622655491     M           1970
# 4   717277229    33222324480     F           1994

# %%
endereco_pessoa_fisica.head()
# Out:
#     id_pessoa_fisica    nom_cidade                     des_estado
# 0                 NaN                            NaN                      NaN
# 1   41173256            TREMEMBE                       SAO PAULO
# 2   212014803           SALVADOR                       BAHIA
# 3   252868763           PORTO ALEGRE                   RIO GRANDE DO SUL
# 4   351777344           CORURIPE                       ALAGOAS

# %%
fatec_operacao.head()
# Out:
#     id_opr_cad_pos    doc_cli         tip_cli    qtd_pcl    dat_vct_ult_pcl   \
# 0               NaN             NaN        NaN        NaN                NaN
# 1   0f503289-dfb      87308050371     F          52         20112023
# 2   683ea107-f2e      54355614187     F          36         06112022
# 3   d8e48899-58d      92265948819     F          NULL       NULL
# 4   5909262c-526      104455393515    F          82         20112019
#
#     vlr_ctrd_fta_tfm    sdo_ddr_tfm    vlr_ctrd      \
# 0                 NaN            NaN            NaN
# 1   NULL                259741.1685    28511582.7
# 2   140141.5236         NULL           NULL
# 3   NULL                0.0000         NULL
# 4   NULL                1520.5905      27626512.71
#
#     id_ult_rss_opr                          id_mdl    cod_mdl    id_fnt
# 0                                     NaN       NaN        NaN       NaN
# 1   25e351cc-ec4e-4a47-861e-834f2aa1dc13    14        C01        99
# 2   a1f18524-8a4f-40a5-ba31-6fbff83bfd58    10        B05        99
# 3   63149b03-b3bd-41e3-9b33-86661155bbaf    15        D01        179
# 4   40367466-b381-4452-add6-641eafb6b1be    14        C01        99

# %%
fatec_movimento.head()
# Out:
#     id_opr_cad_pos    id_mvt_cad_pos    dat_vct     qtd_pcl_vnc   \
# 0               NaN               NaN         NaN            NaN
# 1   ed78c2f2-fd2      64d85edf-8b3      15062019    NULL
# 2   84706050-586      3e537b64-340      10042019    NULL
# 3   7b3bc686-d7f      930e64c5-777      17022019    NULL
# 4   57a7735b-83e      79bac911-7a0      10022019    NULL
#
#     qtd_pcl_pgr    vlr_tot_fat_tfm    vlr_min_fat_tfm    vlr_pcl_tfm   \
# 0            NaN                NaN                NaN            NaN
# 1   NULL           NULL               NULL               2728.3476
# 2   NULL           2195.7135          329.3049           NULL
# 3   NULL           3791.8644          56870.4600         NULL
# 4   NULL           NULL               NULL               1284.6519
#
#     tip_mvt    prd
# 0        NaN     NaN
# 1   ANT        M
# 2   ANT        NULL
# 3   ANT        NULL
# 4   ANT        M

# %%
fatec_pagamento.head()
# Out:
#     id_opr_cad_pos    id_mvt_cad_pos    id_pgt_cad_pos    dat_pgt    \
# 0               NaN               NaN               NaN         NaN
# 1   c8176e21-845      cd596c84-3fe      f4ef9e73-e02      13102019
# 2   a3fad4d7-ad7      3736da82-cd3      cffcab96-2b4      01032020
# 3   7fd6249b-4cf      f66a2496-e0a      b021cf9e-409      07122018
# 4   90fb53f6-225      0e3217ed-88e      72854add-8b9      07082019
#
#     dat_vct_tfm            vlr_pgt_tfm    cod_mdl    cmd
# 0                    NaN            NaN        NaN    NaN
# 1   2019-10-13 03:00:00    591.3060       D01        E
# 2   2020-03-01 03:00:00    6880.2081      D01        E
# 3   2019-12-12 03:00:00    6553.5303      B05        I
# 4   2019-08-05 03:00:00    5980.6140      C01        I

# %% [markdown]
# ## Redefinindo os nomes das colunas

# %%
# Definindo os novos nomes das colunas:

pessoa_fisica.columns = ['id', 'cpf', 'idc_sexo', 'ano_dat_nascimento']
endereco_pessoa_fisica.columns = ['id_pessoa_fisica', 'nom_cidade', 'des_estado']
fatec_operacao.columns = ['id_opr_cad_pos', 'doc_cli', 'tip_cli', 'qtd_pcl', 'dat_vct_ult_pcl', 'vlr_ctrd_fta_tfm', 'sdo_ddr_tfm', 'vlr_ctrd', 'id_ult_rss_opr', 'id_mdl', 'cod_mdl', 'id_fnt']
fatec_movimento.columns =  ['id_opr_cad_pos', 'id_mvt_cad_pos', 'dat_vct', 'qtd_pcl_vnc', 'qtd_pcl_pgr', 'vlr_tot_fat_tfm',	'vlr_min_fat_tfm', 'vlr_pcl_tfm', 'tip_mvt', 'prd']
fatec_pagamento.columns = ['id_opr_cad_pos', 'id_mvt_cad_pos', 'id_pgt_cad_pos', 'dat_pgt', 'dat_vct_tfm', 'vlr_pgt_tfm', 'cod_mdl', 'cmd']

# %%
# Nomeclatura das colunas depois da alteração:

pessoa_fisica.columns
# Out:
# Index(['id', 'cpf', 'idc_sexo', 'ano_dat_nascimento'], dtype='object')

# %% [markdown]
# ## Retirando os valores nulos

# %%
# Exemplo da tabela antes de retirar os valores nulos entre as quebras de página:
pessoa_fisica.head()

# Como você pode observar na tabela abaixo, existe linhas entre as quebras de página, que possuem valores nulos
# Out:
#             id             cpf    idc_sexo    ano_dat_nascimento
# 0          NaN             NaN         NaN                   NaN
# 1   804129883    37311167211     M           2000
# 2   246036379    34115266395     M           1969
# 3   218979283    35622655491     M           1970
# 4   717277229    33222324480     F           1994

# %%
# Retirando os valores nulos entre as quebras de página:

pessoa_fisica = pessoa_fisica[(pd.isna(pessoa_fisica['cpf']) != True)]
endereco_pessoa_fisica = endereco_pessoa_fisica[(pd.isna(endereco_pessoa_fisica['id_pessoa_fisica']) != True)]
fatec_operacao = fatec_operacao[(pd.isna(fatec_operacao['id_opr_cad_pos']) != True)]
fatec_movimento = fatec_movimento[(pd.isna(fatec_movimento['id_opr_cad_pos']) != True)]
fatec_pagamento = fatec_pagamento[(pd.isna(fatec_pagamento['id_opr_cad_pos']) != True)]

# %% [markdown]
# ## Retirando as quebras de pagina no DataFrame

# %%
# Usando a váriavel anterior para retirar as quebrar de página:

pessoa_fisica = pessoa_fisica[(pessoa_fisica['id'] != coluna_pessoa_fisica)]
endereco_pessoa_fisica = endereco_pessoa_fisica[(endereco_pessoa_fisica['id_pessoa_fisica'] != coluna_endereco_pessoa_fisica)]
fatec_operacao = fatec_operacao[(fatec_operacao['id_opr_cad_pos'] != coluna_fatec_operacao)]
fatec_movimento = fatec_movimento[(fatec_movimento['id_opr_cad_pos'] != coluna_fatec_movimento)]
fatec_pagamento = fatec_pagamento[(fatec_pagamento['id_opr_cad_pos'] != coluna_fatec_pagamento)]

# %%
pessoa_fisica
# Out:
#                id             cpf    idc_sexo    ano_dat_nascimento
# 1      804129883    37311167211     M           2000
# 2      246036379    34115266395     M           1969
# 3      218979283    35622655491     M           1970
# 4      717277229    33222324480     F           1994
# 5      3674219      1505546115      M           1971
# ...           ...             ...         ...                   ...
# 3004   123479485    255051104931    M           1983
# 3005   271099619    223885940544    F           1962
# 3006   209547061    265864987976    F           1975
# 3007   97718872     262208637843    F           1983
# 3008   66330285     255487112307    F           1983
#
# [3000 rows x 4 columns]

# %%
endereco_pessoa_fisica
# Out:
#         id_pessoa_fisica                     nom_cidade  \
# 1      41173256            TREMEMBE
# 2      212014803           SALVADOR
# 3      252868763           PORTO ALEGRE
# 4      351777344           CORURIPE
# 5      84464227            GUAPIACU
# ...                  ...                            ...
# 2571   656352115              RECIFE
# 2572   682771544              BELEM
# 2573   106917520              JABOATAO DOS GUARARAPES
# 2574   343505805              BRASILIA
# 2575   166743768              RIO DE JANEIRO
#
#                    des_estado
# 1      SAO PAULO
# 2      BAHIA
# 3      RIO GRANDE DO SUL
# 4      ALAGOAS
# 5      SAO PAULO
# ...                       ...
# 2571   PERNAMBUCO
# 2572   PARA
# 2573   PERNAMBUCO
# 2574   DISTRITO FEDERAL
# 2575   RIO DE JANEIRO
#
# [2567 rows x 3 columns]

# %%
fatec_operacao
# Out:
#         id_opr_cad_pos         doc_cli    tip_cli    qtd_pcl  \
# 1      0f503289-dfb      87308050371     F          52
# 2      683ea107-f2e      54355614187     F          36
# 3      d8e48899-58d      92265948819     F          NULL
# 4      5909262c-526      104455393515    F          82
# 5      a2baadcc-95a      8642684152      F          65
# ...                ...             ...        ...        ...
# 3004   11bd0eb8-546      213603194469    F          NULL
# 3005   38634b0a-897      252169585344    F          60
# 3006   cebe727e-8b5      247391528715    F          84
# 3007   e6965bba-e4a      249677066973    F          47
# 3008   a5d43fa5-536      258481778859    F          36
#
#         dat_vct_ult_pcl    vlr_ctrd_fta_tfm    sdo_ddr_tfm       vlr_ctrd  \
# 1      20112023           NULL                259741.1685    28511582.7
# 2      06112022           140141.5236         NULL           NULL
# 3      NULL               NULL                0.0000         NULL
# 4      20112019           NULL                1520.5905      27626512.71
# 5      15042020           NULL                8093.7615      26287450.65
# ...                 ...                 ...            ...            ...
# 3004   NULL               NULL                2115.0240      NULL
# 3005   25112018           145296.1440         NULL           NULL
# 3006   10092026           NULL                187834.5642    20333074.29
# 3007   10122021           NULL                48979.6941     30874638.3
# 3008   30042021           74816.1801          NULL           NULL
#
#                               id_ult_rss_opr    id_mdl    cod_mdl    id_fnt
# 1      25e351cc-ec4e-4a47-861e-834f2aa1dc13    14        C01        99
# 2      a1f18524-8a4f-40a5-ba31-6fbff83bfd58    10        B05        99
# 3      63149b03-b3bd-41e3-9b33-86661155bbaf    15        D01        179
# 4      40367466-b381-4452-add6-641eafb6b1be    14        C01        99
# 5      3e99353c-df9a-4164-831d-84fff45cefdf    14        C01        99
# ...                                      ...       ...        ...       ...
# 3004   e6c5bd30-c23a-4134-b733-c3546e9981bb    15        D01        179
# 3005   2274cb1f-602b-4761-bea5-2ef420154a90    10        B05        99
# 3006   5da63c6a-28be-48e4-8a4a-f71bce8a4a53    14        C01        99
# 3007   adbd7ce7-c890-4f12-a581-7c64db1af242    14        C01        99
# 3008   8340c27b-499e-4147-9d29-7268db9bd3bc    10        B05        99
#
# [3000 rows x 12 columns]

# %%
fatec_movimento
# Out:
#          id_opr_cad_pos    id_mvt_cad_pos     dat_vct    qtd_pcl_vnc  \
# 1       ed78c2f2-fd2      64d85edf-8b3      15062019    NULL
# 2       84706050-586      3e537b64-340      10042019    NULL
# 3       7b3bc686-d7f      930e64c5-777      17022019    NULL
# 4       57a7735b-83e      79bac911-7a0      10022019    NULL
# 5       c527b570-ce7      81c011a3-349      10102019    NULL
# ...                 ...               ...         ...            ...
# 54210   a0f565a4-5f7      926699e6-c33      05022020    NULL
# 54211   2487a7a8-367      d97c15c9-6ca      08072019    NULL
# 54212   97257a00-2e6      9b81674c-445      09052019    NULL
# 54213   a8509734-039      9d4a7f3a-f2f      08052019    NULL
# 54214   99d52a6a-1a6      70078d20-73b      25062019    NULL
#
#          qtd_pcl_pgr    vlr_tot_fat_tfm    vlr_min_fat_tfm    vlr_pcl_tfm  \
# 1       NULL           NULL               NULL               2728.3476
# 2       NULL           2195.7135          329.3049           NULL
# 3       NULL           3791.8644          56870.4600         NULL
# 4       NULL           NULL               NULL               1284.6519
# 5       NULL           647.3508           540.4320           NULL
# ...              ...                ...                ...            ...
# 54210   NULL           202.0365           83.4000            NULL
# 54211   NULL           1093.6242          237.6900           NULL
# 54212   NULL           1258.0890          42117.0000         NULL
# 54213   NULL           1395.4488          131630.2200        NULL
# 54214   NULL           48235.1406         7235.0751          NULL
#
#          tip_mvt     prd
# 1       ANT        M
# 2       ANT        NULL
# 3       ANT        NULL
# 4       ANT        M
# 5       ANT        NULL
# ...          ...     ...
# 54210   ANT        NULL
# 54211   ANT        NULL
# 54212   ANT        NULL
# 54213   ANT        NULL
# 54214   ANT        NULL
#
# [54006 rows x 10 columns]

# %%
fatec_pagamento
# Out:
#          id_opr_cad_pos    id_mvt_cad_pos    id_pgt_cad_pos     dat_pgt  \
# 1       c8176e21-845      cd596c84-3fe      f4ef9e73-e02      13102019
# 2       a3fad4d7-ad7      3736da82-cd3      cffcab96-2b4      01032020
# 3       7fd6249b-4cf      f66a2496-e0a      b021cf9e-409      07122018
# 4       90fb53f6-225      0e3217ed-88e      72854add-8b9      07082019
# 5       e4d0eaed-0c6      48a5b038-4ed      453f0f88-7e9      11022019
# ...                 ...               ...               ...         ...
# 40225   e14a9706-52d      43b3441c-754      35e935bc-d21      30052019
# 40226   85358af2-ed5      c626dc8b-97e      36f315e7-e0d      03102019
# 40227   9bcffcf1-cc9      70d620ea-8ab      4a0a4f3a-211      10122018
# 40228   e005d7d2-30a      30b4dc7d-ab1      5f353f39-89c      03062019
# 40229   7a7beaae-fdc      7050f372-c97      53d35450-a14      22032019
#
#                  dat_vct_tfm    vlr_pgt_tfm    cod_mdl    cmd
# 1       2019-10-13 03:00:00    591.3060       D01        E
# 2       2020-03-01 03:00:00    6880.2081      D01        E
# 3       2019-12-12 03:00:00    6553.5303      B05        I
# 4       2019-08-05 03:00:00    5980.6140      C01        I
# 5       2019-02-28 03:00:00    2301.7983      B05        I
# ...                      ...            ...        ...    ...
# 40225   2019-06-01 03:00:00    1418.8425      D01        I
# 40226   2019-10-12 03:00:00    2155.9734      C01        I
# 40227   2018-12-10 02:00:00    3343.1307      C01        I
# 40228   2019-06-03 03:00:00    6117.9738      B05        I
# 40229   2019-03-18 03:00:00    49.9983        D01        I
#
# [40073 rows x 8 columns]
