# %% [markdown]
# # INDICADOR: INTEGRIDADE

# %% [markdown]
# ## 00. Declarando Bibliotecas

# %%
import pandas as pd

# %% [markdown]
# ## 1. Criação de dataframes e adaptação

# %% [markdown]
# #### 1.1 Criando os dataframes das bases de dados em Excel

# %%
modalidade = pd.read_excel('dados/STG_MDL.xls')
pagamento = pd.read_excel('dados/STG_PGT.xls')
movimento = pd.read_excel('dados/STG_MVT_CRD.xls')
operacao = pd.read_excel('dados/STG_OPR_ITT.xls')
fonte = pd.read_excel('dados/STG_FNT_ITT.xls')

# %% [markdown]
# #### 1.2 Aplicando padrão de nome de colunas estabelecido pela equipe, apenas para etapa de manipulação

# %%
modalidade.columns = ['id_mod', 'codigo_mod', 'descri_mod', 'DAT_INC_DBO']
pagamento.columns = ['id_pagamento', 'vlr_pago', 'data_vencimento', 'codigo_mod', 'qtd_clientes', 'qtd_pagamento', 'id_fonte', 'tipo_pessoa', 'DAT_RSS_FNT_ITT', 'DAT_INC_DBO']
movimento.columns = ['id_movi', 'vlr_saldo', 'vlr_total_fat', 'vlr_min_fat', 'vlr_parcela_fat', 'qtd_clientes', 'qtd_movi', 'tipo_pessoa', 'id_fonte', 'codigo_mod', 'DAT_RSS_FNT_ITT', 'DAT_INC_DBO']
operacao.columns = ['id_operacao', 'vlr_contrato', 'qtd_parcelas', 'vlr_devido', 'qtd_clientes', 'qtd_operacao', 'id_fonte', 'id_mod', 'tipo_pessoa', 'DAT_RSS_FNT_ITT', 'DAT_INC_DBO']
fonte.columns = ['id_fonte', 'cnpj', 'complemento', 'NOM_COM', 'NOM_RAZ_SCL', 'DAT_INC_DBO']

# %% [markdown]
# #### 1.3 Criando o atributo .nome para facilitar a exibição das tabelas nas respectivas funções

# %%
fonte.nome = 'Fonte'
movimento.nome = 'Movimentações'
operacao.nome = 'Operações'
pagamento.nome = 'Pagamento'
modalidade.nome = 'Modalidade'

# %% [markdown]
# ## 2. Apresentação da situação atual dos dados

# %%
fonte.head(10)
# Out:
#    id_fonte         cnpj  complemento NOM_COM NOM_RAZ_SCL  \
# 0       137   2427884087         2805     NMN         NMN
# 1       183  12182674487         2635     NMN         NMN
# 2       197  16167328168         1802     NMN         NMN
# 3       267    279925978         2329     NMN         NMN
# 4       322  20579036860         2397     NMN         NMN
# 5       336   6574465046         2465     NMN         NMN
# 6       343    306428723         2380     NMN         NMN
# 7       356   7422524275         2550     NMN         NMN
# 8       380    707714471         1904     NMN         NMN
# 9       394    582504932         3094     NMN         NMN
#
#                DAT_INC_DBO
# 0  2019-12-19 13:43:41.914
# 1  2019-12-19 13:43:41.914
# 2  2019-12-19 13:43:41.914
# 3  2019-12-19 13:43:41.914
# 4  2019-12-19 13:43:41.914
# 5  2019-12-19 13:43:41.914
# 6  2019-12-19 13:43:41.914
# 7  2019-12-19 13:43:41.914
# 8  2019-12-19 13:43:41.914
# 9  2019-12-19 13:43:41.914

# %%
modalidade.head(10)
# Out:
#    id_mod codigo_mod                                descri_mod  \
# 0      17        E02                  ADIANTAMENTO DEPOSITANTE
# 1      13        B99                     OUTROS FINANCIAMENTOS
# 2      15        D01                         CARTAO DE CREDITO
# 3      19        G01                       TITULOS DESCONTADOS
# 4       2        A02              EMPRESTIMO - CAPITAL DE GIRO
# 5       3        A04              EMPRESTIMO - CREDITO PESSOAL
# 6      16        E01         CHEQUE ESPECIAL E CONTA GARANTIDA
# 7       8        B03          FINANCIAMENTO - IMOBILIARIOS SFH
# 8       7        B02  FINANCIAMENTO - IMPORTACAO  E EXPORTACAO
# 9       4        A05                 EMPRESTIMO - MICROCREDITO
#
#                DAT_INC_DBO
# 0  2019-12-19 13:37:34.759
# 1  2019-12-19 13:37:34.759
# 2  2019-12-19 13:37:34.759
# 3  2019-12-19 13:37:34.759
# 4  2019-12-19 13:37:34.759
# 5  2019-12-19 13:37:34.759
# 6  2019-12-19 13:37:34.759
# 7  2019-12-19 13:37:34.759
# 8  2019-12-19 13:37:34.759
# 9  2019-12-19 13:37:34.759

# %%
movimento
# Out:
#     id_movi     vlr_saldo  vlr_total_fat   vlr_min_fat  vlr_parcela_fat  \
# 0         1           NaN            NaN           NaN     4.595517e+10
# 1         2           NaN            NaN           NaN     7.387237e+10
# 2         3           NaN            NaN           NaN     2.868181e+09
# 3         4           NaN            NaN           NaN     6.111251e+10
# 4         5           NaN            NaN           NaN     2.152609e+06
# 5         6           NaN            NaN           NaN     4.607337e+08
# 6         7           NaN            NaN           NaN     2.638331e+11
# 7         8           NaN            NaN           NaN     1.838029e+11
# 8         9           NaN            NaN           NaN     9.738713e+08
# 9        10  2.181758e+10            NaN           NaN              NaN
# 10       11           NaN            NaN           NaN     9.496722e+09
# 11       12           NaN            NaN           NaN     3.556795e+11
# 12       13           NaN            NaN           NaN     1.834447e+09
# 13       14           NaN            NaN           NaN     1.733950e+08
# 14       15           NaN   1.932767e+12  6.071738e+11              NaN
#
#     qtd_clientes  qtd_movi tipo_pessoa  id_fonte codigo_mod DAT_RSS_FNT_ITT  \
# 0          37186    677272           F        67        C01      2020-01-16
# 1         307070   2741111           F        67        B99      2020-01-16
# 2            601      1964           F        67        B01      2020-01-16
# 3          18820    244041           F        67        B03      2020-01-16
# 4              2         4           F        67        F01      2020-01-16
# 5             33       329           F        67        B07      2020-01-16
# 6         721836  10020532           F        67        A04      2020-01-16
# 7         135773   1797516           F        67        B05      2020-01-16
# 8           5061     38003           F        67        A05      2020-01-16
# 9         194378    194921           F        67        E01      2020-01-16
# 10          1890    123559           F        67        G01      2020-01-16
# 11        494442  19241809           F        67        A01      2020-01-16
# 12         46495    230867           F        67        A99      2020-01-16
# 13            43       330           F        67        B06      2020-01-16
# 14       1840240  21748501           F        67        D01      2020-01-16
#
#                 DAT_INC_DBO
# 0   2020-01-17 17:49:17.524
# 1   2020-01-17 17:49:17.524
# 2   2020-01-17 17:49:17.524
# 3   2020-01-17 17:49:17.524
# 4   2020-01-17 17:49:17.524
# 5   2020-01-17 17:49:17.524
# 6   2020-01-17 17:49:17.524
# 7   2020-01-17 17:49:17.524
# 8   2020-01-17 17:49:17.524
# 9   2020-01-17 17:49:17.524
# 10  2020-01-17 17:49:17.524
# 11  2020-01-17 17:49:17.524
# 12  2020-01-17 17:49:17.524
# 13  2020-01-17 17:49:17.524
# 14  2020-01-17 17:49:17.524

# %%
operacao.head(15)
# Out:
#     id_operacao  vlr_contrato  qtd_parcelas  vlr_devido  qtd_clientes  \
# 0             1           NaN            45         NaN           341
# 1             2           NaN            63         NaN           103
# 2             3           NaN            22         NaN            15
# 3             4           NaN            48         NaN             9
# 4             5           NaN           290         NaN             3
# 5             6           NaN           109         NaN             1
# 6             7    24231168.0            20  14774641.0             6
# 7             8           NaN            59         NaN           235
# 8             9           NaN            38         NaN            14
# 9            10           NaN           117         NaN             4
# 10           11           NaN           332         NaN             1
# 11           12           NaN            53         NaN             7
# 12           13           NaN            13         NaN           141
# 13           14           NaN           250         NaN            12
# 14           15    83720000.0           158  61146076.0             4
#
#     qtd_operacao  id_fonte id_mod tipo_pessoa DAT_RSS_FNT_ITT  \
# 0            358        67    A04           F      2020-01-16
# 1            108        67    B99           F      2020-01-16
# 2             16        67    B05           F      2020-01-16
# 3              9        67    B03           F      2020-01-16
# 4              3        67    B03           F      2020-01-16
# 5              1        67    B99           F      2020-01-16
# 6              7        67    C01           F      2020-01-16
# 7            253        67    A04           F      2020-01-16
# 8             14        67    B05           F      2020-01-16
# 9              4        67    A01           F      2020-01-16
# 10             1        67    B03           F      2020-01-16
# 11             7        67    B05           F      2020-01-16
# 12           143        67    A99           F      2020-01-16
# 13            12        67    B03           F      2020-01-16
# 14             4        67    C01           F      2020-01-16
#
#                DAT_INC_DBO
# 0   2020-01-27 10:49:48.15
# 1   2020-01-27 10:49:48.15
# 2   2020-01-27 10:49:48.15
# 3   2020-01-27 10:49:48.15
# 4   2020-01-27 10:49:48.15
# 5   2020-01-27 10:49:48.15
# 6   2020-01-27 10:49:48.15
# 7   2020-01-27 10:49:48.15
# 8   2020-01-27 10:49:48.15
# 9   2020-01-27 10:49:48.15
# 10  2020-01-27 10:49:48.15
# 11  2020-01-27 10:49:48.15
# 12  2020-01-27 10:49:48.15
# 13  2020-01-27 10:49:48.15
# 14  2020-01-27 10:49:48.15

# %%
pagamento.head(10)
# Out:
#    id_pagamento  vlr_pago  data_vencimento codigo_mod  qtd_clientes  \
# 0           451    515711         16082022        A04            22
# 1           452     60763         26102020        A99             2
# 2           453   8588195         24022019        G01            22
# 3           454    369084         24062018        B99            16
# 4           455     13054         20022021        B99             1
# 5           456   1206954          4012018        A04             3
# 6           457     21684         24122018        B07             1
# 7           458    341157         27032016        B99            10
# 8           459      3929         21032018        B05             1
# 9           460     12700         28112018        A05             3
#
#    qtd_pagamento  id_fonte tipo_pessoa DAT_RSS_FNT_ITT  \
# 0             22        67           F      2020-01-16
# 1              2        67           F      2020-01-16
# 2             22        67           F      2020-01-16
# 3             23        67           F      2020-01-16
# 4              1        67           F      2020-01-16
# 5              5        67           F      2020-01-16
# 6              1        67           F      2020-01-16
# 7             11        67           F      2020-01-16
# 8              1        67           F      2020-01-16
# 9              3        67           F      2020-01-16
#
#                DAT_INC_DBO
# 0  2020-01-17 17:50:42.746
# 1  2020-01-17 17:50:42.746
# 2  2020-01-17 17:50:42.746
# 3  2020-01-17 17:50:42.746
# 4  2020-01-17 17:50:42.746
# 5  2020-01-17 17:50:42.746
# 6  2020-01-17 17:50:42.746
# 7  2020-01-17 17:50:42.746
# 8  2020-01-17 17:50:42.746
# 9  2020-01-17 17:50:42.746

# %% [markdown]
# ## 3. Funções para análise da Integridade dos dados

# %% [markdown]
# #### 3.1 Ocultar todos os campos nulos sem afetar a integridade. (Condições especificas para as tabelas movimento e operação).
# Ponderando que, na análise abaixo, dividimos a função em dois dataframes para facilitar a análise, sendo um dataframe somente COM a modalidade C01 e outro dataframe SEM a modalidade C01. Separamos o dataframe em duas partes pois para análisar a modalidade C01, precisamos de condições especificas, como a necessidade das colunas "vlr_contrato" e "vlr_devido". Os valores nulos nas colunas "vlr_contrato" e "vlr_devido" só existem quando não há o atributo da modalidade "C01". Os valores nulos que existem não prejudicam a integridade das informações, mas para melhor apresentação em análise foram ocultados.

# %% [markdown]
# ##### 3.1.1 Sem a modalidade "CO1" - Tabela 'Operação'

# %%
# Definindo a caracteristica especifica (Dataframe SEM o C01) do dataframe
id_sem_C01 = operacao[(operacao['id_mod'] != 'C01')]

# Criando o dataframe com as caracteristicas especificas e utilizando as colunas necessárias para a análise
df_sem_C01 = pd.DataFrame(id_sem_C01, columns = ['id_operacao', 'qtd_parcelas', 'qtd_clientes', 'qtd_operacao', 'id_fonte', 'id_mod', 'tipo_pessoa', 'DAT_RSS_FNT_ITT', 'DAT_INC_DBO'])

# %%
df_sem_C01
# Out:
#      id_operacao  qtd_parcelas  qtd_clientes  qtd_operacao  id_fonte id_mod  \
# 0              1            45           341           358        67    A04
# 1              2            63           103           108        67    B99
# 2              3            22            15            16        67    B05
# 3              4            48             9             9        67    B03
# 4              5           290             3             3        67    B03
# ..           ...           ...           ...           ...       ...    ...
# 885          886           102             1             1        67    A04
# 887          888           228             7             7        67    B03
# 888          889            52             1             1        67    B03
# 889          890           182             1             1        67    B03
# 890          891           186             2             2        67    B03
#
#     tipo_pessoa DAT_RSS_FNT_ITT             DAT_INC_DBO
# 0             F      2020-01-16  2020-01-27 10:49:48.15
# 1             F      2020-01-16  2020-01-27 10:49:48.15
# 2             F      2020-01-16  2020-01-27 10:49:48.15
# 3             F      2020-01-16  2020-01-27 10:49:48.15
# 4             F      2020-01-16  2020-01-27 10:49:48.15
# ..          ...             ...                     ...
# 885           F      2020-01-16  2020-01-27 10:49:48.15
# 887           F      2020-01-16  2020-01-27 10:49:48.15
# 888           F      2020-01-16  2020-01-27 10:49:48.15
# 889           F      2020-01-16  2020-01-27 10:49:48.15
# 890           F      2020-01-16  2020-01-27 10:49:48.15
#
# [705 rows x 9 columns]

# %%
df_sem_C01.isnull().sum() #conta quantos dados nulos (NÃO HÁ DADOS NULOS QUANDO "OCULTAMOS" as colunas 'vlr_contrato' e 'vlr_devido')
# Out:
# id_operacao        0
# qtd_parcelas       0
# qtd_clientes       0
# qtd_operacao       0
# id_fonte           0
# id_mod             0
# tipo_pessoa        0
# DAT_RSS_FNT_ITT    0
# DAT_INC_DBO        0
# dtype: int64

# %%
pd.DataFrame(df_sem_C01['id_mod'].value_counts()) #trazendo ID e suas modalidades
# Out:
#      id_mod
# B03     214
# A01     122
# A04     112
# B99     104
# B05      71
# A99      35
# A05      20
# B01      19
# B06       4
# B07       2
# G01       1
# F01       1

# %% [markdown]
# ##### 3.1.2 Com a modalidade "C01" - Tabela 'Operação'

# %%
# Definindo as caracteristicas especificas (Dataframe COM o C01) do dataframe
id_mod_C01 = operacao[(operacao['id_mod'] == 'C01')]

# Criando o dataframe com as caracteristicas especificas e com todas as colunas
df_com_C01 = pd.DataFrame(id_mod_C01)

# %%
df_com_C01
# Out:
#      id_operacao  vlr_contrato  qtd_parcelas   vlr_devido  qtd_clientes  \
# 6              7    24231168.0            20   14774641.0             6
# 14            15    83720000.0           158   61146076.0             4
# 18            19   453409414.0            82  345569291.0            86
# 19            20   831887355.0            70  387293236.0           150
# 22            23   168720000.0           117   47151818.0            10
# ..           ...           ...           ...          ...           ...
# 853          854   235637981.0            93  123012165.0            21
# 859          860    62075885.0            17   17357289.0             7
# 869          870   213020000.0           176  132743567.0            12
# 873          874   174842840.0           103   61800347.0            12
# 886          887    85699650.0           105   57998876.0            14
#
#      qtd_operacao  id_fonte id_mod tipo_pessoa DAT_RSS_FNT_ITT  \
# 6               7        67    C01           F      2020-01-16
# 14              4        67    C01           F      2020-01-16
# 18             93        67    C01           F      2020-01-16
# 19            171        67    C01           F      2020-01-16
# 22             10        67    C01           F      2020-01-16
# ..            ...       ...    ...         ...             ...
# 853            22        67    C01           F      2020-01-16
# 859            15        67    C01           F      2020-01-16
# 869            15        67    C01           F      2020-01-16
# 873            15        67    C01           F      2020-01-16
# 886            15        67    C01           F      2020-01-16
#
#                 DAT_INC_DBO
# 6    2020-01-27 10:49:48.15
# 14   2020-01-27 10:49:48.15
# 18   2020-01-27 10:49:48.15
# 19   2020-01-27 10:49:48.15
# 22   2020-01-27 10:49:48.15
# ..                      ...
# 853  2020-01-27 10:49:48.15
# 859  2020-01-27 10:49:48.15
# 869  2020-01-27 10:49:48.15
# 873  2020-01-27 10:49:48.15
# 886  2020-01-27 10:49:48.15
#
# [186 rows x 11 columns]

# %%
df_com_C01.isnull().sum() #conta quantos dados nulos (NÃO HÁ DADOS NULOS QUANDO EXISTE SOMENTE A MODALIDADE C01)
# Out:
# id_operacao        0
# vlr_contrato       0
# qtd_parcelas       0
# vlr_devido         0
# qtd_clientes       0
# qtd_operacao       0
# id_fonte           0
# id_mod             0
# tipo_pessoa        0
# DAT_RSS_FNT_ITT    0
# DAT_INC_DBO        0
# dtype: int64

# %% [markdown]
# ##### 3.2 Verifica na Tabela fonte se o Nome Comercial e Razão Social são Strings

# %%
def checar_string(Fonte):
    NOM = pd.DataFrame(Fonte, columns = ['NOM_COM', 'NOM_RAZ_SCL'])
    NOM_COM = []
    RAZ_SCL = []
    cont_a = 0
    cont_b = 0
    for x in NOM.columns:
        for y in NOM[x]:
            
            if x == 'NOM_COM':
                cont_a += 1
                if type(y) != str:
                    NOM_COM.append(cont_a)
                    
            if x == 'NOM_RAZ_SCL':
                cont_b += 1
                if type(y) != str:
                    RAZ_SCL.append(cont_b)
                    
    print(f'''
    Foram identificados {len(NOM_COM)} dados incoerentes na coluna Nome Comercial
    e na coluna Nome Razão Social foram identificados {len(RAZ_SCL)} dados incoerentes''')
    
            
FONTE = checar_string(fonte)
FONTE
# Out:
#     Foram identificados 0 dados incoerentes na coluna Nome Comercial
#     e na coluna Nome Razão Social foram identificados 0 dados incoerentes

# %% [markdown]
# #### 3.2 Validação de CNPJs
# Nessa função o objetivo é você validar todos os CNPJ's, verificando os numeros de digitos

# %%
valida_cnpj = pd.DataFrame(fonte, columns = ['cnpj', 'complemento'])

# %%
# Declarando listas e variaveis
cnpj = []
complemento = []
certos_cnpj = []
certos_complemento = []

# Verificando se a primeira parte do CPJN possui 10 digitos
for x in valida_cnpj['cnpj']:
    if len(str(x)) == 10:
        cnpj.append(str(x))
    else:
        cnpj.append('a')

# Verificando se a segunda parte do CNPJ possui 4 digitos
for x in valida_cnpj['complemento']:
    if len(str(x)) == 4:
        complemento.append(str(x))
    else:
        complemento.append('a')

# Verificando se ao somar as duas partes do CNPJ irá dar 14 digitos
for x in range(valida_cnpj.shape[0]):
    if len(cnpj[x]) + len(complemento[x]) == 14:
        certos_cnpj.append(cnpj[x])
        certos_complemento.append(complemento[x])
        
validos = fonte['cnpj'].isin(certos_cnpj)
cnpj_validos = fonte[validos]
cnpj_validos
# Out:
#      id_fonte        cnpj  complemento  \
# 0         137  2427884087         2805
# 5         336  6574465046         2465
# 7         356  7422524275         2550
# 13        481  9804044092         2958
# 16        505  1178913365         2703
# ..        ...         ...          ...
# 992       969  2290535681         2006
# 994       997  2615960085         2125
# 995      1016  2492494372         1938
# 997         3  3388575864         2159
# 999        20  3820722477         1989
#
#                                     NOM_COM  \
# 0                                       NMN
# 5                                       NMN
# 7                                       NMN
# 13                                      NMN
# 16                                      NMN
# ..                                      ...
# 992                                     NMN
# 994                                     NMN
# 995                                     NMN
# 997                               MPM VVSTM
# 999  MR PMRTNJRS MMNPP JJ VNVJSTVMJNTP S.M.
#
#                                 NOM_RAZ_SCL              DAT_INC_DBO
# 0                                       NMN  2019-12-19 13:43:41.914
# 5                                       NMN  2019-12-19 13:43:41.914
# 7                                       NMN  2019-12-19 13:43:41.914
# 13                                      NMN  2019-12-19 13:43:41.914
# 16                                      NMN  2019-12-19 13:43:41.914
# ..                                      ...                      ...
# 992                                     NMN  2019-12-19 13:43:41.914
# 994                                     NMN  2019-12-19 13:43:41.914
# 995                                     NMN  2019-12-19 13:43:41.914
# 997                      MPM VVSTM SJRVVPPS  2019-12-19 13:43:41.914
# 999  MR PMRTNJRS MMNPP JJ VNVJSTVMJNTP S.M.  2019-12-19 13:43:41.914
#
# [433 rows x 6 columns]

# %%
fonte[validos].shape[0]
# Out:
# 433

# %% [markdown]
# #### 3.3 Validação IDs
# Nesta função, temos o objetivo de identificar se os ID's possuem continuidade, e indentificar os ID's que estão faltando.
#
# Exemplo:
# (1,2,3,5,7,8,9)
#
# Estão faltando os ID's 4 e 6.

# %%
def gap_id(df):
    IDs = df[df.columns[0]].to_list()
    padrao = range(min(IDs), max(IDs) + 1)
    faltante = list()
    for ID in padrao:
        if ID not in IDs:
            faltante.append(ID)
    if len(faltante) == 0:
        print(f"100% dos ID's da tabela {df.nome} são sequenciais, pois não apresentam nenhum gap.")
        return
    print(f"Existe um gap de {(len(faltante)/len(list(IDs))) * 100:.3f}% na sequência de ID's da tabela {df.nome}")

# %%
analisa_id_fonte = gap_id(fonte)
analisa_id_operacao = gap_id(operacao)
analisa_id_modalidade = gap_id(modalidade)
analisa_id_pagamento = gap_id(pagamento)
analisa_id_movimentacao = gap_id(movimento)

# %%
gap_id(fonte)
# Out:
# Existe um gap de 1.687% na sequência de ID's da tabela Fonte

# %% [markdown]
# #### 3.4 Validação das modalidades nas tabelas

# %%
def valida_modalidade(dataframe):
    invalidos = list()
    referencia = [ID for ID in modalidade['cod_modalidade']]
    amostra = [ID for ID in dataframe['id_mod']]
    for ID in amostra:
      if ID not in referencia:
        invalidos.append(ID)

    if len(invalidos) == 0:
      print(f"100% dos ID's da tabela {dataframe.nome} estão referenciados na tabela de fontes")

    else:
      porcentagem = (len(invalidos) / len(amostra)) * 100
      print(f"{porcentagem}% dos ID's da tabela de {dataframe.nome} não estão referenciados na tabela de fontes. Os ID's incorretos estão listados abaixo:")
      print(invalidos)

# %% [markdown]
# #### 3.5 Formatando data de vencimento

# %%
'Formata a data de vencimento'
def Formata_DATAVENCIMENTO(DataFrame):
    DataCerta = []
    DataFrame = DataFrame['data_vencimento'].to_list()
    for i in DataFrame:
        if len(str(i)) == 8:
            dia = str(i)[0:2]
            mes = str(i)[2:4]
            ano = str(i)[4:]
            if int(dia) < 32 and int(mes) < 13:
                dat = str(i)[0:2] + '-' + str(i)[2:4] + '-' + str(i)[4:]
            else:
                dat = 'Data possui informações invalidas'  
            DataCerta.append(dat)
    return DataCerta



Formata_DATAVENCIMENTO(pagamento)
# Out:
# ['16-08-2022',
#  '26-10-2020',
#  '24-02-2019',
#  '24-06-2018',
#  '20-02-2021',
#  '24-12-2018',
#  '27-03-2016',
#  '21-03-2018',
#  '28-11-2018',
#  '13-03-2019',
#  '19-12-2018',
#  '16-06-2016',
#  '16-03-2018',
#  '20-04-2021',
#  '19-06-2018',
#  '21-07-2019',
#  '27-11-2018',
#  '15-05-2025',
#  '14-12-2018',
#  '25-12-2018',
#  '17-04-2019',
#  '10-05-2019',
#  '26-12-2019',
#  '18-01-2019',
#  '28-08-2018',
#  '24-09-2018',
#  '31-07-2026',
#  '24-11-2023',
#  '28-06-2017',
#  '28-12-2019',
#  '10-01-2015',
