# %%
from data import fatec_operacao, fatec_pagamento, fatec_movimento

# %%
import pandas as pd

# %%
fatec_operacao
# Out:
#      id_opr_cad_pos       doc_cli tip_cli  qtd_pcl  dat_vct_ult_pcl  \
# 0      0f503289-dfb   87308050371       F     52.0       20112023.0
# 1      683ea107-f2e   54355614187       F     36.0        6112022.0
# 2      d8e48899-58d   92265948819       F      NaN              NaN
# 3      5909262c-526  104455393515       F     82.0       20112019.0
# 4      a2baadcc-95a    8642684152       F     65.0       15042020.0
# ...             ...           ...     ...      ...              ...
# 2995   11bd0eb8-546  213603194469       F      NaN              NaN
# 2996   38634b0a-897  252169585344       F     60.0       25112018.0
# 2997   cebe727e-8b5  247391528715       F     84.0       10092026.0
# 2998   e6965bba-e4a  249677066973       F     47.0       10122021.0
# 2999   a5d43fa5-536  258481778859       F     36.0       30042021.0
#
#       vlr_ctrd_fta_tfm  sdo_ddr_tfm     vlr_ctrd  \
# 0                  NaN  259741.1685  28511582.70
# ...

# %%
fatec_operacao.to_excel("dados/importados/fatec_opr.xlsx", sheet_name = "tabela 1", index = False)

# %%
if 'jose' in fatec_operacao:
    print("TEM")
else:
    print("Fudeo")
# Out:
# Fudeo

# %%
fatec_movimento.head()
# Out:
#   id_opr_cad_pos id_mvt_cad_pos   dat_vct qtd_pcl_vnc qtd_pcl_pgr  \
# 0   ed78c2f2-fd2   64d85edf-8b3  15062019        NULL        NULL
# 1   84706050-586   3e537b64-340  10042019        NULL        NULL
# 2   7b3bc686-d7f   930e64c5-777  17022019        NULL        NULL
# 3   57a7735b-83e   79bac911-7a0  10022019        NULL        NULL
# 4   c527b570-ce7   81c011a3-349  10102019        NULL        NULL
#
#   vlr_tot_fat_tfm vlr_min_fat_tfm vlr_pcl_tfm tip_mvt   prd  id_fnt cod_mdl
# 0            NULL            NULL   2728.3476     ANT     M      88     B05
# 1       2195.7135        329.3049        NULL     ANT  NULL       7     D01
# 2       3791.8644      56870.4600        NULL     ANT  NULL     953     D01
# 3            NULL            NULL   1284.6519     ANT     M     781     C01
# 4        647.3508        540.4320        NULL     ANT  NULL     781     D01

# %%
def consistencia(series_base, series_referencia, fonte):
